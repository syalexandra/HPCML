# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
plt.plot([0.1,6.67],[3,200], color='blue',label='DRAM 30GB/s')
plt.plot([6.67,10],[200,200],color='green',label='CPU 200GFLOPS')
plt.plot([6.67,6.67],[0,200],color='red',linestyle='dashed')

plt.plot(0.956/7.653,0.956,color='tab:blue',marker='o',label="C1(1000000)",markersize=3,linestyle='None')
plt.plot(0.861/6.887,0.861,color='tab:orange',marker='o',label="C1(300000000)",markersize=3,linestyle='None')
plt.plot(2.157/17.262,2.157,color='tab:green',marker='o',label="C2(1000000)",markersize=3,linestyle='None')
plt.plot(1.138/9.107,1.138,color='tab:purple',marker='o',label="C2(300000000)",markersize=3,linestyle='None')
plt.plot(1.011/8.090,1.011,color='tab:brown',marker='o',label="C3(1000000)",markersize=3,linestyle='None')
plt.plot(0.5434/4.348,0.5434,color='tab:pink',marker='o',label="C3(300000000)",markersize=3,linestyle='None')
plt.plot(0.00139/0.0111,0.00139,color='tab:gray',marker='o',label="C4(1000000)",markersize=3,linestyle='None')
plt.plot(2.319/18.557,2.319,color='tab:olive',marker='o',label="C5(1000000)",markersize=3,linestyle='None')
plt.plot(1.529/12.235,1.529,color='tab:cyan',marker='o',label="C5(300000000)",markersize=3,linestyle='None')

plt.yscale('log')
plt.xscale('log')
plt.xlabel("AI (FLOP/byte) (log-scale)")
plt.ylabel("Throughput (GFLOP/s) (log-scale)")
plt.legend(loc=(1.04, 0))

plt.show()
